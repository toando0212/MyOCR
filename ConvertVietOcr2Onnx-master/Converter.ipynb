# %%
import matplotlib.pyplot as plt
from PIL import Image
from tool.config import Cfg
from tool.translate import build_model, process_input, translate
import torch
import onnxruntime
import numpy as np

# %%
config = Cfg.load_config_from_file('./config/vgg-seq2seq.yml')
config['cnn']['pretrained']=False
config['device'] = 'cpu'
model, vocab = build_model(config)
weight_path = './weight/transformerocr.pth'
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# load weight
model.load_state_dict(torch.load(weight_path, map_location=torch.device(config['device'])))
model = model.eval()

# %% [markdown]
# ## Export CNN part

# %%
def convert_cnn_part(img, save_path, model, max_seq_length=128, sos_token=1, eos_token=2): 
    with torch.no_grad(): 
        src = model.cnn(img)
        torch.onnx.export(model.cnn, img, save_path, export_params=True, opset_version=11, do_constant_folding=True, verbose=True, input_names=['img'], output_names=['output'])
    
    return src

# %%
img = torch.rand(1, 3, 32, 475)
src = convert_cnn_part(img, './weight/cnn.onnx', model)

# %% [markdown]
# ## Export encoder part

# %%
# def convert_encoder_part(model, src, save_path): 
#     encoder_outputs, hidden = model.transformer.encoder(src) 
#     torch.onnx.export(model.transformer.encoder, src, save_path, export_params=True, opset_version=11, do_constant_folding=True, input_names=['src'], output_names=['encoder_outputs', 'hidden']) 
#     return hidden, encoder_outputs

# %%
# hidden, encoder_outputs = convert_encoder_part(model, src, './weight/encoder.onnx')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with GRU can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(

# %%
src = torch.rand(236, 1, 256)  # hoặc đúng kiểu output thực tế của CNN
torch.onnx.export(
    model.transformer.encoder, src, "./weight/encoder.onnx",
    export_params=True, opset_version=11, do_constant_folding=True,
    input_names=['src'], output_names=['encoder_outputs', 'hidden']
      # KHÔNG truyền dynamic_axes
)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with GRU can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(

# %% [markdown]
# ## Export decoder part

# %%
# def convert_decoder_part(model, tgt, hidden, encoder_outputs, save_path):
#     tgt = tgt[-1]
    
#     torch.onnx.export(model.transformer.decoder,
#         (tgt, hidden, encoder_outputs),
#         save_path,
#         export_params=True,
#         opset_version=11,
#         do_constant_folding=True,
#         input_names=['tgt', 'hidden', 'encoder_outputs'],
#         output_names=['output', 'hidden_out', 'last']
#         )

tgt = torch.LongTensor([1])  # hoặc [1, 1] tuỳ model
hidden = torch.rand(1, 256)
encoder_outputs = torch.rand(236, 1, 256)
torch.onnx.export(
    model.transformer.decoder,
    (tgt, hidden, encoder_outputs),
    "./weight/decoder.onnx",
    export_params=True, opset_version=11, do_constant_folding=True,
    input_names=['tgt', 'hidden', 'encoder_outputs'],
    output_names=['output', 'hidden_out', 'last']
    # KHÔNG truyền dynamic_axes
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 17
#      15 hidden = torch.rand(1, 256)
#      16 encoder_outputs = torch.rand(236, 1, 256)
# ---> 17 torch.onnx.export(
#      18     model.transformer.decoder,
#      19     (tgt, hidden, encoder_outputs),
#      20     "./weight/decoder.onnx",
#      21     export_params=True, opset_version=11, do_constant_folding=True,
#      22     input_names=['tgt', 'hidden', 'encoder_outputs'],
#      23     output_names=['output', 'hidden_out', 'last']
#      24     # KHÔNG truyền dynamic_axes
#      25 )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\__init__.py:396, in export(model, args, f, kwargs, export_params, verbose, input_names, output_names, opset_version, dynamic_axes, keep_initializers_as_inputs, dynamo, external_data, dynamic_shapes, custom_translation_table, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, training, operator_export_type, do_constant_folding, custom_opsets, export_modules_as_functions, autograd_inlining)
#     390 if dynamic_shapes:
#     391     raise ValueError(
#     392         "The exporter only supports dynamic shapes "
#     393         "through parameter dynamic_axes when dynamo=False."
#     394     )
# --> 396 export(
#     397     model,
#     398     args,
#     399     f,  # type: ignore[arg-type]
#     400     kwargs=kwargs,
#     401     export_params=export_params,
#     402     verbose=verbose is True,
#     403     input_names=input_names,
#     404     output_names=output_names,
#     405     opset_version=opset_version,
#     406     dynamic_axes=dynamic_axes,
#     407     keep_initializers_as_inputs=keep_initializers_as_inputs,
#     408     training=training,
#     409     operator_export_type=operator_export_type,
#     410     do_constant_folding=do_constant_folding,
#     411     custom_opsets=custom_opsets,
#     412     export_modules_as_functions=export_modules_as_functions,
#     413     autograd_inlining=autograd_inlining,
#     414 )
#     415 return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\utils.py:529, in export(model, args, f, kwargs, export_params, verbose, training, input_names, output_names, operator_export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, custom_opsets, export_modules_as_functions, autograd_inlining)
#     526 if kwargs is not None:
#     527     args = args + (kwargs,)
# --> 529 _export(
#     530     model,
#     531     args,
#     532     f,
#     533     export_params,
#     534     verbose,
#     535     training,
#     536     input_names,
#     537     output_names,
#     538     operator_export_type=operator_export_type,
#     539     opset_version=opset_version,
#     540     do_constant_folding=do_constant_folding,
#     541     dynamic_axes=dynamic_axes,
#     542     keep_initializers_as_inputs=keep_initializers_as_inputs,
#     543     custom_opsets=custom_opsets,
#     544     export_modules_as_functions=export_modules_as_functions,
#     545     autograd_inlining=autograd_inlining,
#     546 )
#     548 return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\utils.py:1467, in _export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, fixed_batch_size, custom_opsets, add_node_names, onnx_shape_inference, export_modules_as_functions, autograd_inlining)
#    1464     dynamic_axes = {}
#    1465 _validate_dynamic_axes(dynamic_axes, model, input_names, output_names)
# -> 1467 graph, params_dict, torch_out = _model_to_graph(
#    1468     model,
#    1469     args,
#    1470     verbose,
#    1471     input_names,
#    1472     output_names,
#    1473     operator_export_type,
#    1474     val_do_constant_folding,
#    1475     fixed_batch_size=fixed_batch_size,
#    1476     training=training,
#    1477     dynamic_axes=dynamic_axes,
#    1478 )
#    1480 if custom_opsets is None:
#    1481     custom_opsets = {}
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\utils.py:1087, in _model_to_graph(model, args, verbose, input_names, output_names, operator_export_type, do_constant_folding, _disable_torch_constant_prop, fixed_batch_size, training, dynamic_axes)
#    1084     args = (args,)
#    1086 model = _pre_trace_quant_model(model, args)
# -> 1087 graph, params, torch_out, module = _create_jit_graph(model, args)
#    1088 params_dict = _get_named_param_dict(graph, params)
#    1090 try:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\utils.py:971, in _create_jit_graph(model, args)
#     966     graph = _C._propagate_and_assign_input_shapes(
#     967         graph, flattened_args, param_count_list, False, False
#     968     )
#     969     return graph, params, torch_out, None
# --> 971 graph, torch_out = _trace_and_get_graph_from_model(model, args)
#     972 _C._jit_pass_onnx_lint(graph)
#     973 state_dict = torch.jit._unique_state_dict(model)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\onnx\utils.py:878, in _trace_and_get_graph_from_model(model, args)
#     876 prev_autocast_cache_enabled = torch.is_autocast_cache_enabled()
#     877 torch.set_autocast_cache_enabled(False)
# --> 878 trace_graph, torch_out, inputs_states = torch.jit._get_trace_graph(
#     879     model,
#     880     args,
#     881     strict=False,
#     882     _force_outplace=False,
#     883     _return_inputs_states=True,
#     884 )
#     885 torch.set_autocast_cache_enabled(prev_autocast_cache_enabled)
#     887 warn_on_static_input_change(inputs_states)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\jit\_trace.py:1501, in _get_trace_graph(f, args, kwargs, strict, _force_outplace, return_inputs, _return_inputs_states)
#    1499 if not isinstance(args, tuple):
#    1500     args = (args,)
# -> 1501 outs = ONNXTracedModule(
#    1502     f, strict, _force_outplace, return_inputs, _return_inputs_states
#    1503 )(*args, **kwargs)
#    1504 return outs
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\jit\_trace.py:138, in ONNXTracedModule.forward(self, *args)
#     135     else:
#     136         return tuple(out_vars)
# --> 138 graph, _out = torch._C._create_graph_by_tracing(
#     139     wrapper,
#     140     in_vars + module_state,
#     141     _create_interpreter_name_lookup_fn(),
#     142     self.strict,
#     143     self._force_outplace,
#     144 )
#     146 if self._return_inputs:
#     147     return graph, outs[0], ret_inputs[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\jit\_trace.py:129, in ONNXTracedModule.forward.<locals>.wrapper(*args)
#     127 if self._return_inputs_states:
#     128     inputs_states.append(_unflatten(in_args, in_desc))
# --> 129 outs.append(self.inner(*trace_inputs))
#     130 if self._return_inputs_states:
#     131     inputs_states[0] = (inputs_states[0], trace_inputs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1741, in Module._slow_forward(self, *input, **kwargs)
#    1739         recording_scopes = False
#    1740 try:
# -> 1741     result = self.forward(*input, **kwargs)
#    1742 finally:
#    1743     if recording_scopes:
#
# File d:\MyOCR\MyOCR\ConvertVietOcr2Onnx-master\model\seqmodel\seq2seq.py:79, in Decoder.forward(self, input, hidden, encoder_outputs)
#      75 input = input.unsqueeze(0)
#      77 embedded = self.dropout(self.embedding(input))
# ---> 79 a = self.attention(hidden, encoder_outputs)
#      81 a = a.unsqueeze(1)
#      83 encoder_outputs = encoder_outputs.permute(1, 0, 2)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1741, in Module._slow_forward(self, *input, **kwargs)
#    1739         recording_scopes = False
#    1740 try:
# -> 1741     result = self.forward(*input, **kwargs)
#    1742 finally:
#    1743     if recording_scopes:
#
# File d:\MyOCR\MyOCR\ConvertVietOcr2Onnx-master\model\seqmodel\seq2seq.py:50, in Attention.forward(self, hidden, encoder_outputs)
#      46 hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
#      48 encoder_outputs = encoder_outputs.permute(1, 0, 2)
# ---> 50 energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2)))
#      52 attention = self.v(energy).squeeze(2)
#      54 return F.softmax(attention, dim = 1)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1741, in Module._slow_forward(self, *input, **kwargs)
#    1739         recording_scopes = False
#    1740 try:
# -> 1741     result = self.forward(*input, **kwargs)
#    1742 finally:
#    1743     if recording_scopes:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (236x512 and 768x256)

# %%
device = img.device
tgt = torch.LongTensor([[1] * len(img)]).to(device)

# %%
convert_decoder_part(model, tgt, hidden, encoder_outputs, './weight/decoder.onnx')
# Out:
# d:\MyOCR\MyOCR\ConvertVietOcr2Onnx-master\model\seqmodel\seq2seq.py:93: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert (output == hidden).all()

# %% [markdown]
# ## Load and check model

# %%
import onnx

# %%
cnn = onnx.load('./weight/cnn.onnx')
decoder = onnx.load('./weight/encoder.onnx')
encoder = onnx.load('./weight/decoder.onnx')

# %%
# confirm model has valid schema
onnx.checker.check_model(cnn)
onnx.checker.check_model(decoder)
onnx.checker.check_model(encoder)

# %%
# # Print a human readable representation of the graph
onnx.helper.printable_graph(encoder.graph)
# Out:
# 'graph torch-jit-export (\n  %tgt[INT64, 1]\n  %hidden[FLOAT, 1x256]\n  %encoder_outputs[FLOAT, channel_inputx1x512]\n) initializers (\n  %attention.attn.bias[FLOAT, 256]\n  %embedding.weight[FLOAT, 233x256]\n  %fc_out.weight[FLOAT, 233x1024]\n  %fc_out.bias[FLOAT, 233]\n  %116[INT64, 1]\n  %117[INT64, 1]\n  %118[INT64, 1]\n  %119[INT64, 1]\n  %120[FLOAT, 768x256]\n  %121[FLOAT, 256x1]\n  %139[FLOAT, 1x768x768]\n  %140[FLOAT, 1x768x256]\n  %141[FLOAT, 1x1536]\n) {\n  %13 = Unsqueeze[axes = [0]](%tgt)\n  %14 = Gather(%embedding.weight, %13)\n  %15 = Shape(%encoder_outputs)\n  %16 = Constant[value = <Scalar Tensor []>]()\n  %17 = Gather[axis = 0](%15, %16)\n  %18 = Unsqueeze[axes = [1]](%hidden)\n  %22 = Unsqueeze[axes = [0]](%17)\n  %24 = Concat[axis = 0](%116, %22, %117)\n  %26 = Unsqueeze[axes = [0]](%17)\n  %28 = Concat[axis = 0](%118, %26, %119)\n  %29 = Shape(%24)\n  %30 = ConstantOfShape[value = <Tensor>](%29)\n  %31 = Expand(%18, %30)\n  %32 = Tile(%31, %28)\n  %33 = Transpose[perm = [1, 0, 2]](%encoder_outputs)\n  %34 = Concat[axis = 2](%32, %33)\n  %36 = MatMul(%34, %120)\n  %37 = Add(%36, %attention.attn.bias)\n  %38 = Tanh(%37)\n  %40 = MatMul(%38, %121)\n  %41 = Squeeze[axes = [2]](%40)\n  %42 = Softmax[axis = 1](%41)\n  %43 = Unsqueeze[axes = [1]](%42)\n  %44 = Transpose[perm = [1, 0, 2]](%encoder_outputs)\n  %45 = MatMul(%43, %44)\n  %46 = Transpose[perm = [1, 0, 2]](%45)\n  %47 = Concat[axis = 2](%14, %46)\n  %48 = Unsqueeze[axes = [0]](%hidden)\n  %106, %107 = GRU[hidden_size = 256, linear_before_reset = 1](%47, %139, %140, %141, %, %48)\n  %108 = Squeeze[axes = [1]](%106)\n  %109 = Squeeze[axes = [0]](%14)\n  %110 = Squeeze[axes = [0]](%108)\n  %111 = Squeeze[axes = [0]](%46)\n  %112 = Concat[axis = 1](%110, %111, %109)\n  %output = Gemm[alpha = 1, beta = 1, transB = 1](%112, %fc_out.weight, %fc_out.bias)\n  %hidden_out = Squeeze[axes = [0]](%107)\n  %last = Squeeze[axes = [1]](%43)\n  return %output, %hidden_out, %last\n}'

# %% [markdown]
# ## Inference directly

# %%
img = Image.open('./sample/35944.png')
img = process_input(img, config['dataset']['image_height'], 
                config['dataset']['image_min_width'], config['dataset']['image_max_width'])  
img = img.to(config['device'])

# %%
s = translate(img, model)[0].tolist()
s = vocab.decode(s)
s
# Out:
# 'Mâm non: 141 thí sinh'

# %% [markdown]
# ## Inference with ONNX Runtime's Python API

# %%
# create inference session
cnn_session = onnxruntime.InferenceSession("./weight/cnn.onnx")
encoder_session = onnxruntime.InferenceSession("./weight/encoder.onnx")
decoder_session = onnxruntime.InferenceSession("./weight/decoder.onnx")

# %%
def translate_onnx(img, session, max_seq_length=128, sos_token=1, eos_token=2):
    """data: BxCxHxW"""
    cnn_session, encoder_session, decoder_session = session
    
    # create cnn input
    cnn_input = {cnn_session.get_inputs()[0].name: img}
    src = cnn_session.run(None, cnn_input)
    
    # create encoder input
    encoder_input = {encoder_session.get_inputs()[0].name: src[0]}
    encoder_outputs, hidden = encoder_session.run(None, encoder_input)
    translated_sentence = [[sos_token] * len(img)]
    max_length = 0

    while max_length <= max_seq_length and not all(
        np.any(np.asarray(translated_sentence).T == eos_token, axis=1)
    ):
        tgt_inp = translated_sentence
        decoder_input = {decoder_session.get_inputs()[0].name: tgt_inp[-1], decoder_session.get_inputs()[1].name: hidden, decoder_session.get_inputs()[2].name: encoder_outputs}

        output, hidden, _ = decoder_session.run(None, decoder_input)
        output = np.expand_dims(output, axis=1)
        output = torch.Tensor(output)

        values, indices = torch.topk(output, 1)
        indices = indices[:, -1, 0]
        indices = indices.tolist()

        translated_sentence.append(indices)
        max_length += 1

        del output

    translated_sentence = np.asarray(translated_sentence).T

    return translated_sentence

# %%
session = (cnn_session, encoder_session, decoder_session)
s = translate_onnx(np.array(img), session)[0].tolist()
s = vocab.decode(s)
s
# Out:
# 'Mâm non: 141 thí sinh'
